# %%
import numpy as np
import pandas as pd
import Surfaces
import Giotto2Mapper
import gtda.mapper
import plotly.graph_objects as go
import plotly

# %%
maps = pd.read_csv('cover_comparison_mapper_graphs.csv', dtype = {'Unnamed: 0':gtda.mapper.pipeline.MapperPipeline, 'g1Torus':plotly.graph_objects.FigureWidget, 'g2Torus':plotly.graph_objects.FigureWidget})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 maps = pd.read_csv('cover_comparison_mapper_graphs.csv', dtype = {'Unnamed: 0':gtda.mapper.pipeline.MapperPipeline, 'g1Torus':plotly.graph_objects.FigureWidget, 'g2Torus':plotly.graph_objects.FigureWidget})
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
maps
# Out:
#                                            Unnamed: 0  \
# 0   Projection(columns=[0, 1])_CubicalCover(n_inte...
# 1   Projection(columns=[0, 1])_CubicalCover(n_inte...
# 2   Projection(columns=[0, 1])_CubicalCover(n_inte...
# 3           Projection(columns=[0, 1])_CubicalCover()
# 4   Projection(columns=[0, 1])_CubicalCover(overla...
# ..                                                ...
# 84   PCA(n_components=2)_CircularCover(n_intervals=5)
# 85  PCA(n_components=2)_CircularCover(n_intervals=...
# 86  PCA(n_components=2)_CircularCover(n_intervals=...
# 87                PCA(n_components=2)_CircularCover()
# 88  PCA(n_components=2)_CircularCover(overlap_frac...
#
#                                               g1Torus  \
# 0   FigureWidget({\n    'data': [{'hoverinfo': 'no...
# 1   FigureWidget({\n    'data': [{'hoverinfo': 'no...
# 2   FigureWidget({\n    'data': [{'hoverinfo': 'no...
# 3   FigureWidget({\n    'data': [{'hoverinfo': 'no...
# ...

# %%
pca1 = maps['g1Torus'][87]

# %%
new_im = go.FigureWidget()

# %%
type(print(pca1))
# Out:
# FigureWidg
# NoneType

# %%
type(new_im)
# Out:
# plotly.graph_objs._figurewidget.FigureWidget

# %%
new_im.data
# Out:
# ()

# %%
pca1.str.remove
# Out:
# "FigureWidget({\n    'data': [{'hoverinfo': 'none',\n              'line': {'color': '#888', 'width': 1},\n              'mode': 'lines',\n              'name': 'edge_trace',\n              'type': 'scatter3d',\n              'uid': '0fdac8de-89a5-4277-b58c-500f365c0ea3',\n              'x': [-1.1772216361153878, -0.463815308533167, None, ...,\n                    -0.1418236102818892, -0.03531713421475258, None],\n              'y': [-4.019619821208883, -3.8493307814862687, None, ...,\n                    -2.0720823727075133, -1.0886268012377036, None],\n              'z': [2.670408273293313, 3.334849802299447, None, ...,\n                    3.6876608216845, 3.6669318051761586, None]},\n             {'hoverinfo': 'text',\n              'hoverlabel': {'bgcolor': [#306a8e, #2d708e, #297b8e, #2c738e,\n                                         #26828e, #2a788e, #2d718e, #355f8d,\n                                         #24898d, #2a798e, #277f8e, #297a8e,\n                               
# ...
